# %%
import numpy as np
from modules.DLA_model import Diffusion
from tqdm import tqdm
from modules.dla_testing import successive_over_relaxation, animate_diffusion, run_dla_simulation_v2

# %%
grid_size = 20
diff = Diffusion(grid_size)

num_iterations = 20

results, clusters = run_dla_simulation_v2(diff, num_iterations)

animate_diffusion(results, clusters, save_animation=True, animation_name='dla.mp4')
# Out:
# Iteration: 100%|██████████| 20/20 [00:00<00:00, 23.06it/s]
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
